# %% [markdown]
# **Import the Packages**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **Read the Data**

# %%
path=r'C:\Users\kanch\OneDrive\Naresh IT\Data science\data files\Loan Prediction\train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# $Head$
#
# $df.head()$
# - it gives bydefault 5 rows
# df.head()

# %%
loan_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
loan_df.head(3)
# Out:
#     Loan_ID Gender Married Dependents Education Self_Employed  \
# 0  LP001002   Male      No          0  Graduate            No
# 1  LP001003   Male     Yes          1  Graduate            No
# 2  LP001005   Male     Yes          0  Graduate           Yes
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y

# %% [markdown]
# $Tail$
#
# $df.tail()$
#
# - it gives last rows
# - by default 5 rows

# %%
loan_df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
loan_df.tail(3)
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 611             1.0         Urban           Y
# 612             1.0         Urban           Y
# 613             0.0     Semiurban           N

# %% [markdown]
# $df.shape$
#
# **Number of colmns and Number of rows**
#
# - it gives the shape of the dataset i.e no of columns and no.of rows
# - for $shape$ funcation no need to provide Peranthasis i.e '$()$'

# %%
loan_df.shape
# Out:
# (614, 13)

# %% [markdown]
# $df.size$
#
# **how many indices are there provided by size**
#
# - it gives the total number of values provided in df
# - for $size$ no need to provide the peranthasis i.e '()'

# %%
loan_df.size
# Out:
# 7982

# %%
614 *13
# Out:
# 7982

# %% [markdown]
# $df.columns$
#
# - it gives the total columns of the data set

# %%
loan_df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# $dtypes$
#
# **data types**
#
# - This command gives the data type for every column

# %%
loan_df.dtypes
# Out:
# Loan_ID               object
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History       float64
# Property_Area         object
# Loan_Status           object
# dtype: object

# %% [markdown]
# $task$-$1$
#
# **Extaract NUmerical columns and categorical column seperetly by using dtypes output**

# %%
# Convert above one into dictionary
# Key and values
# if for list 
d1=dict(loan_df.dtypes)
# for i in d1:
#     if d1[i]=='object':
#     print(i)

cat = [i for i in d1 if d1[i]=='object']
num = [i for i in d1 if d1[i]!='object']

# %%
print('Categorical columns')
cat
# Out:
# Categorical columns
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %%
print('Numerical Columns')
num
# Out:
# Numerical Columns
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
# Categorical data availabale
loan_df.select_dtypes(include='object').columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
loan_df.select_dtypes(exclude='object').columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')

# %% [markdown]
# $isnull$
#
# **Identify if data has any missing values or Null values**

# %%
loan_df.isnull().sum()
# True menas (yes) there is a null value
# False means (No) there is no null value
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# **Percentage of missing values for each column**

# %%
percentage_missing_values = loan_df.isnull().sum()*100/len(loan_df)
percentage_missing_values
# Out:
# Loan_ID              0.000000
# Gender               2.117264
# Married              0.488599
# Dependents           2.442997
# Education            0.000000
# Self_Employed        5.211726
# ApplicantIncome      0.000000
# CoapplicantIncome    0.000000
# LoanAmount           3.583062
# Loan_Amount_Term     2.280130
# Credit_History       8.143322
# Property_Area        0.000000
# Loan_Status          0.000000
# dtype: float64

# %% [markdown]
# **Filling the missing values**
#
# $1.fillna()$
#
#     - The $fillna()$ method allows you to replace missing  values with a   specified value or method (such as mean, median, mode or forward / backward fill.)
#
#     - $df.fillna(df.mean(),inplace = True)$
#
# $2.Replacing with Specific values:$
#
#     - You can replace missinf values with specific contacts(e.g., 0, -1, 'Unknown') using the $fillna()$ method
#
#     - To replace missing values with 0:
#
#         - $df.fillna(0,inplace= True)
#
# $3.Forward Fill (fill) and Backward Fill (fill):$
#
#     - Use the $ffill$ method to fill missing values with the previous non-null
#       value in the column
#     - Use the $bfill$ method to fill missing values with the next non-null           value in the column.
#     - To forward fill missing values:
#         $df.fillna(method= ffill,inplace=True)$
#
# $4.Interpolation:$
#
#     - Interpolation estimates missing values based on existing data points
#     - Use the $interpolate()$ method.
#     - $df.interpolate(method='linear',inplace =True)

# %%
loan_df.fillna(method='bfill', inplace = True)

# %%
loan_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %% [markdown]
# ### $Drop$ $duplicates$
#
# - $df.drop$_$duplicates()$
# - **It Drop duplicate values**

# %%
loan_df.drop_duplicates()
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df['Dependents'].replace({'3+':3},inplace=True)

# %%
loan_df['Dependents']= loan_df['Dependents'].astype(int)

# %% [markdown]
# $info$
#
# - it give the information of the dataset like cloumns and no of null values and datatypes of each column

# %%
loan_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             614 non-null    object
#  2   Married            614 non-null    object
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    object
#  5   Self_Employed      614 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         614 non-null    float64
#  9   Loan_Amount_Term   614 non-null    float64
#  10  Credit_History     614 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int32(1), int64(1), object(7)
# memory usage: 60.1+ KB

# %%
len(loan_df)
# Out:
# 614

# %% [markdown]
# $take$-$loc$-$iloc$

# %%
loan_df.take((2,5,7))
# 2,3,4 are the columns or rows
# axis=1 reference as columns
# axis=0 reference as rows
# by default axis = 0, rows
# Out:
#     Loan_ID Gender Married  Dependents Education Self_Employed  \
# 2  LP001005   Male     Yes           0  Graduate           Yes
# 5  LP001011   Male     Yes           2  Graduate           Yes
# 7  LP001014   Male     Yes           3  Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 2             3000                0.0        66.0             360.0
# 5             5417             4196.0       267.0             360.0
# 7             3036             2504.0       158.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 2             1.0         Urban           Y
# 5             1.0         Urban           Y
# 7             0.0     Semiurban           N

# %%
loan_df.take([2,5,7],axis=1)
# python index start with 0
# Out:
#     Married Self_Employed  CoapplicantIncome
# 0        No            No                0.0
# 1       Yes            No             1508.0
# 2       Yes           Yes                0.0
# 3       Yes            No             2358.0
# 4        No            No                0.0
# ..      ...           ...                ...
# 609      No            No                0.0
# 610     Yes            No                0.0
# 611     Yes            No              240.0
# 612     Yes            No                0.0
# 613      No           Yes                0.0
#
# [614 rows x 3 columns]

# %%
loan_df.take([100,200,300])
# Out:
#       Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 100  LP001345   Male     Yes           2  Not Graduate            No
# 200  LP001674   Male     Yes           1  Not Graduate            No
# 300  LP001964   Male     Yes           0  Not Graduate            No
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 100             4288             3263.0       133.0             180.0
# 200             2600             2500.0        90.0             360.0
# 300             1800             2934.0        93.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 100             1.0         Urban           Y
# 200             1.0     Semiurban           Y
# 300             0.0         Urban           N

# %%
# I want 100,200,300 rows form 4,8,11 columns

# %%
loan_df.take([100,200,300]).take([4,8,11],axis=1)
# Out:
#         Education  LoanAmount Property_Area
# 100  Not Graduate       133.0         Urban
# 200  Not Graduate        90.0     Semiurban
# 300  Not Graduate        93.0         Urban

# %% [markdown]
# **Note:**
#     - Take does not take rows and cloumns at a time
#
# $iloc$
#
# - $df.iloc[<rows>,<columns>]$
# - $df.iloc[<start:end>,<start:end>]$
# - rows=[]
# - cols=[]
# - $df.iloc[rows,cols]$

# %%
loan_df[5:10] # sll the columns
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 5  LP001011   Male     Yes           2      Graduate           Yes
# 6  LP001013   Male     Yes           0  Not Graduate            No
# 7  LP001014   Male     Yes           3      Graduate            No
# 8  LP001018   Male     Yes           2      Graduate            No
# 9  LP001020   Male     Yes           1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 5             5417             4196.0       267.0             360.0
# 6             2333             1516.0        95.0             360.0
# 7             3036             2504.0       158.0             360.0
# 8             4006             1526.0       168.0             360.0
# 9            12841            10968.0       349.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 5             1.0         Urban           Y
# 6             1.0         Urban           Y
# ...

# %%
loan_df.iloc[5:10,2:5] # specific rows and specific columns
# Out:
#   Married  Dependents     Education
# 5     Yes           2      Graduate
# 6     Yes           0  Not Graduate
# 7     Yes           3      Graduate
# 8     Yes           2      Graduate
# 9     Yes           1      Graduate

# %%
loan_df.iloc[:,2:5]  # all the rows with specific columns

# iloc will consider column incex
# Out:
#     Married  Dependents     Education
# 0        No           0      Graduate
# 1       Yes           1      Graduate
# 2       Yes           0      Graduate
# 3       Yes           0  Not Graduate
# 4        No           0      Graduate
# ..      ...         ...           ...
# 609      No           0      Graduate
# 610     Yes           3      Graduate
# 611     Yes           1      Graduate
# 612     Yes           2      Graduate
# 613      No           0      Graduate
#
# [614 rows x 3 columns]

# %%
loan_df.loc[[100,200,300],['Loan_Amount_Term']]

# loc will consider directly column name
# Out:
#      Loan_Amount_Term
# 100             180.0
# 200             360.0
# 300             360.0

# %% [markdown]
# **Catgorical Cloumns Analysis**

# %%
loan_df.head()
# Out:
#     Loan_ID Gender Married  Dependents     Education Self_Employed  \
# 0  LP001002   Male      No           0      Graduate            No
# 1  LP001003   Male     Yes           1      Graduate            No
# 2  LP001005   Male     Yes           0      Graduate           Yes
# 3  LP001006   Male     Yes           0  Not Graduate            No
# 4  LP001008   Male      No           0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# **$Unique$ $labels$ $for$ $each$ $columns$**

# %%
con=loan_df[['Gender']] == 'Male'
len(con)
# Out:
# 614

# %%
con = loan_df[['Gender']]== 'Female'
len(con)
# Out:
# 614

# %%
con=loan_df[['Gender']] == 'Male'
con
# Out:
#      Gender
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# ..      ...
# 609   False
# 610    True
# 611    True
# 612    True
# 613   False
#
# [614 rows x 1 columns]

# %%
loan_df['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
loan_df[['Gender']]=='Female'
# Out:
#      Gender
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# ..      ...
# 609    True
# 610   False
# 611   False
# 612   False
# 613    True
#
# [614 rows x 1 columns]

# %%
cols = ['Gender','Married','Education','Property_Area']
loan_df[cols]
# Out:
#      Gender Married     Education Property_Area
# 0      Male      No      Graduate         Urban
# 1      Male     Yes      Graduate         Rural
# 2      Male     Yes      Graduate         Urban
# 3      Male     Yes  Not Graduate         Urban
# 4      Male      No      Graduate         Urban
# ..      ...     ...           ...           ...
# 609  Female      No      Graduate         Rural
# 610    Male     Yes      Graduate         Rural
# 611    Male     Yes      Graduate         Urban
# 612    Male     Yes      Graduate         Urban
# 613  Female      No      Graduate     Semiurban
#
# [614 rows x 4 columns]

# %%
count = loan_df['Property_Area']=='Urban'
len(loan_df[count])
# Out:
# 202

# %%
count = loan_df['Property_Area']=='Rural'
len(loan_df[count])
# Out:
# 179

# %%
count = loan_df['Property_Area']=='Semiurban'
len(loan_df[count])
# Out:
# 233

# %% [markdown]
# **Cetagorical columns analysis**
#
# $GENDER$

# %%
loan_df['Gender']
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3        Male
# 4        Male
#         ...
# 609    Female
# 610      Male
# 611      Male
# 612      Male
# 613    Female
# Name: Gender, Length: 614, dtype: object

# %%
loan_df['Gender'].isnull().sum()
# Out:
# 0

# %%
Male= []
for  i in loan_df['Gender']:
    if i == 'Male':
        Male.append(i)
print(f'Number of male persons: {len(Male)}')
# Out:
# Number of male persons: 501

# %%
FeMale= []
for  i in loan_df['Gender']:
    if i == 'Female':
        FeMale.append(i)
print(f'Number of Female persons: {len(FeMale)}')
# Out:
# Number of Female persons: 113

# %%
Gender_unique = loan_df['Gender'].unique()
count_of_gender=[]
for i in Gender_unique:
    con = loan_df['Gender']== i
    count_of_gender.append(len(loan_df[con]))
Gender_df = pd.DataFrame(zip(Gender_unique,count_of_gender),columns=['Gender','count_of_gender'])

# %%
Gender_df
# Out:
#    Gender  count_of_gender
# 0    Male              501
# 1  Female              113

# %%
plt.bar('Gender','count_of_gender',data=Gender_df)
plt.xlabel('Gender')
plt.ylabel('Count_of_Gender')
plt.title('Bar Chart on Unique Gender')
plt.show()

# %% [markdown]
# $Married$

# %%
No_count=[]
Yes_count=[]
for i in loan_df['Married']:
    if i == 'No':
        No_count.append(i)
    else:
        Yes_count.append(i)
print(len(No_count))
print(len(Yes_count))
# Out:
# 215
# 399

# %%
Married_unique=loan_df['Married'].unique()
count_of_married_or_not = []
for i in Married_unique:
    con = loan_df['Married']==i
    count_of_married_or_not.append(len(loan_df[con]))
Married_df = pd.DataFrame(zip(Married_unique,count_of_married_or_not),columns=['Married', 'count'])
Married_df
# Out:
#   Married  count
# 0      No    215
# 1     Yes    399

# %% [markdown]
# **$Value$ $Counts$**

# %%
Married_vc = loan_df['Married'].value_counts()
l1 = Married_vc.keys()
l2 = Married_vc.values
Married_vc_df = pd.DataFrame(zip(l1,l2),columns=['Married','count'])
Married_vc_df
# Out:
#   Married  count
# 0     Yes    399
# 1      No    215

# %%
Married_vc_df[['count'][0]]
# Out:
# 0    399
# 1    215
# Name: count, dtype: int64

# %% [markdown]
# **Bar graph**

# %%
plt.bar('Married','count',data=Married_df)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **Education**

# %%
loan_education = loan_df['Education'].value_counts()
l1 = loan_education.keys()
l2 = loan_education.values
loan_education_df = pd.DataFrame(zip(l1,l2),columns=['Education','count']) 
#########################################################
plt.bar('Education','count',data=loan_education_df)
# Out:
# <BarContainer object of 2 artists>

# %% [markdown]
# **$Property$ $Area$**

# %%
property_area = loan_df['Property_Area'].unique()
area_count = []
for i in property_area:
    con = loan_df['Property_Area'] == i
    area_count.append(len(loan_df[con]))
property_area_df = pd.DataFrame(zip(property_area,area_count),columns=['Property_area','count'])
################################################################################

property_area_vc = loan_df['Property_Area'].value_counts()
l1 = property_area_vc.keys()
l2 = property_area_vc.values
property_area_vc_df = pd.DataFrame(zip(l1,l2),columns=['Property_area','count'])
################################################################################

plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Bar chart for Property_area_df')
plt.bar('Property_area','count',data= property_area_df)
plt.xlabel('Property_Area')
plt.ylabel('Count')
##############################################################################

plt.subplot(1,2,2)
plt.title('Bar chart for Property_area__vc_df')
plt.bar('Property_area','count',data= property_area_vc_df)
plt.xlabel('Property_Area')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# $Loan$ $Status$

# %%
loan_status = loan_df['Loan_Status'].unique()
status_count = []
for i in loan_status:
    con = loan_df['Loan_Status'] == i
    status_count.append(len(loan_df[con]))
loan_status_df = pd.DataFrame(zip(loan_status,status_count),columns=['Loan_status','count'])
loan_status_df
# Out:
#   Loan_status  count
# 0           Y    422
# 1           N    192

# %%
loan_status = loan_df['Loan_Status'].unique()
status_count = []
for i in loan_status:
    con = loan_df['Loan_Status'] == i
    status_count.append(len(loan_df[con]))
loan_status_df = pd.DataFrame(zip(loan_status,status_count),columns=['Loan_status','count'])
################################################################################

loan_status_vc = loan_df['Loan_Status'].value_counts()
l1 = loan_status_vc.keys()
l2 = loan_status_vc.values
loan_status_vc_df = pd.DataFrame(zip(l1,l2),columns=['Loan_status','count'])
################################################################################

plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.title('Bar chart for loan_status_df')
plt.bar('Loan_status','count',data= loan_status_df)
plt.xlabel('Loan_status')
plt.ylabel('Count')
##############################################################################

plt.subplot(1,2,2)
plt.title('Bar chart for loan_status_vc_df')
plt.bar('Loan_status','count',data= loan_status_vc_df)
plt.xlabel('Loan_status')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# - from the above analysis i conclude that value count gives the valuses in a arranged or sorted formate i.e. decessinding order

# %% [markdown]
# **Numerical columns Analysis**

# %% [markdown]
# - Convetring the string columns = num columns

# %%
loan_df['Dependents'].replace({'3+':3},inplace = True)

# %%
loan_df.tail(10)
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 604  LP002959  Female     Yes           1      Graduate            No
# 605  LP002960    Male     Yes           0  Not Graduate            No
# 606  LP002961    Male     Yes           1      Graduate            No
# 607  LP002964    Male     Yes           2  Not Graduate            No
# 608  LP002974    Male     Yes           0      Graduate            No
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes           3      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 604            12000                0.0       496.0             360.0
# ...

# %%
loan_df['Dependents']= loan_df['Dependents'].astype(int)

# %%
num_cols = loan_df.select_dtypes(exclude='object')
num_cols
# Out:
#      Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# 0             0             5849                0.0       128.0
# 1             1             4583             1508.0       128.0
# 2             0             3000                0.0        66.0
# 3             0             2583             2358.0       120.0
# 4             0             6000                0.0       141.0
# ..          ...              ...                ...         ...
# 609           0             2900                0.0        71.0
# 610           3             4106                0.0        40.0
# 611           1             8072              240.0       253.0
# 612           2             7583                0.0       187.0
# 613           0             4583                0.0       133.0
#
#      Loan_Amount_Term  Credit_History
# 0               360.0             1.0
# 1               360.0             1.0
# 2               360.0             1.0
# 3               360.0             1.0
# ...

# %%
num_cols.isnull().sum()*100/len(num_cols)
# Out:
# Dependents           0.0
# ApplicantIncome      0.0
# CoapplicantIncome    0.0
# LoanAmount           0.0
# Loan_Amount_Term     0.0
# Credit_History       0.0
# dtype: float64

# %%
num_cols.describe()
# Out:
#        Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count  614.000000       614.000000         614.000000  614.000000
# mean     0.760586      5403.459283        1621.245798  146.416938
# std      1.012005      6109.041673        2926.248369   84.917398
# min      0.000000       150.000000           0.000000    9.000000
# 25%      0.000000      2877.500000           0.000000  100.000000
# 50%      0.000000      3812.500000        1188.500000  128.000000
# 75%      2.000000      5795.000000        2297.250000  166.750000
# max      3.000000     81000.000000       41667.000000  700.000000
#
#        Loan_Amount_Term  Credit_History
# count        614.000000       614.00000
# mean         342.410423         0.84202
# std           64.428629         0.36502
# min           12.000000         0.00000
# 25%          360.000000         1.00000
# 50%          360.000000         1.00000
# 75%          360.000000         1.00000
# max          480.000000         1.00000

# %% [markdown]
# $LoanAmount$

# %%
loan_df['LoanAmount']
# Out:
# 0      128.0
# 1      128.0
# 2       66.0
# 3      120.0
# 4      141.0
#        ...
# 609     71.0
# 610     40.0
# 611    253.0
# 612    187.0
# 613    133.0
# Name: LoanAmount, Length: 614, dtype: float64

# %%
# count function gives the number of data points present in a data set 
#i.e. no of rows
# we can also use the len function to find the no of data points in a data set
loanAmount_count = loan_df['LoanAmount'].count()
loanAmount_count, len(loan_df['LoanAmount'])
# Out:
# (614, 614)

# %% [markdown]
# $mean$

# %%
loanAmount_mean = loan_df['LoanAmount'].mean()
loanAmount_mean
# Out:
# 146.4169381107492

# %% [markdown]
# $Median$

# %%
loanAmount_median = loan_df['LoanAmount'].median()
loanAmount_median
# Out:
# 128.0

# %% [markdown]
# $Standard$ $Devation(std)$

# %%
laonAmount_std = loan_df['LoanAmount'].std()
laonAmount_std
# Out:
# 84.91739834299949

# %% [markdown]
# $max$ and $min$

# %%
loanAmount_max = loan_df['LoanAmount'].max()
loanAmount_min = loan_df['LoanAmount'].min()
loanAmount_max,loanAmount_min
# Out:
# (700.0, 9.0)

# %% [markdown]
# $percentile$
#
#     - 25%,50%,75%

# %%
loanAmount_25 = np.percentile(loan_df['LoanAmount'],25)
loanAmount_50 = np.percentile(loan_df['LoanAmount'],50)
loanAmount_75 = np.percentile(loan_df['LoanAmount'],75)
loanAmount_25,loanAmount_50,loanAmount_75
# Out:
# (100.0, 128.0, 166.75)

# %% [markdown]
# $Creating$ $a$ $DataFrame$
#
#  - on **LoanAmount** Column

# %%
loanAmount_count = loan_df['LoanAmount'].count()
loanAmount_mean = loan_df['LoanAmount'].mean()
loanAmount_median = loan_df['LoanAmount'].median()
loanAmount_std = loan_df['LoanAmount'].std()
loanAmount_max = loan_df['LoanAmount'].max()
loanAmount_min = loan_df['LoanAmount'].min()
loanAmount_25 = np.percentile(loan_df['LoanAmount'],25)
loanAmount_50 = np.percentile(loan_df['LoanAmount'],50)
loanAmount_75 = np.percentile(loan_df['LoanAmount'],75)


#####################################################################
l = [loanAmount_count,loanAmount_mean,loanAmount_median,loanAmount_std,
     loanAmount_max,loanAmount_min,loanAmount_25,loanAmount_50,loanAmount_75]
cols  = ['LoanAmount_Approved']
index = ['count','mean','median','std','max','min','25%','50%','75%']
LoanAmount_Approved_df=pd.DataFrame(l,columns=cols,index=index)
LoanAmount_Approved_df
# Out:
#         LoanAmount_Approved
# count            614.000000
# mean             146.416938
# median           128.000000
# std               84.917398
# max              700.000000
# min                9.000000
# 25%              100.000000
# 50%              128.000000
# 75%              166.750000

# %% [markdown]
# **Creating a dataset for Numerical Columns**

# %%
#using List
cols =  loan_df.select_dtypes(exclude='object').columns
l = []
for i in cols:
    count = loan_df[i].count()
    mean = loan_df[i].mean()
    median = loan_df[i].median()
    std = loan_df[i].std()
    maxx = loan_df[i].max()
    minn = loan_df[i].min()
    p25 = np.percentile(loan_df[i],25)
    p50 = np.percentile(loan_df[i],50)
    p75 = np.percentile(loan_df[i],75)
    l.append([count,mean,median,std,maxx,minn,p25,p50,p75])

index = ['count','max','min','mean','median','std','25%','50%','75%']
LoanDf_NumericalColumns = pd.DataFrame(zip(l[0],l[1],l[2],l[3],l[4],l[5]),columns=cols,index=index)
LoanDf_NumericalColumns
# Out:
#         Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count   614.000000       614.000000         614.000000  614.000000
# max       0.760586      5403.459283        1621.245798  146.416938
# min       0.000000      3812.500000        1188.500000  128.000000
# mean      1.012005      6109.041673        2926.248369   84.917398
# median    3.000000     81000.000000       41667.000000  700.000000
# std       0.000000       150.000000           0.000000    9.000000
# 25%       0.000000      2877.500000           0.000000  100.000000
# 50%       0.000000      3812.500000        1188.500000  128.000000
# 75%       2.000000      5795.000000        2297.250000  166.750000
#
#         Loan_Amount_Term  Credit_History
# count         614.000000       614.00000
# max           342.410423         0.84202
# min           360.000000         1.00000
# mean           64.428629         0.36502
# median        480.000000         1.00000
# std            12.000000         0.00000
# ...

# %%
# BY  using dectionary
cols =  loan_df.select_dtypes(exclude='object').columns
d = {}
for i in cols:
    count = loan_df[i].count()
    mean = loan_df[i].mean()
    median = loan_df[i].median()
    std = loan_df[i].std()
    maxx = loan_df[i].max()
    minn = loan_df[i].min()
    p25 = np.percentile(loan_df[i],25)
    p50 = np.percentile(loan_df[i],50)
    p75 = np.percentile(loan_df[i],75)
    d[i]=[count,mean,median,std,maxx,minn,p25,p50,p75]
    
index = ['count','max','min','mean','median','std','25%','50%','75%']
LoanDf_NumericalColumns = pd.DataFrame(d,columns=cols,index=index)
LoanDf_NumericalColumns
# Out:
#         Dependents  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# count   614.000000       614.000000         614.000000  614.000000
# max       0.760586      5403.459283        1621.245798  146.416938
# min       0.000000      3812.500000        1188.500000  128.000000
# mean      1.012005      6109.041673        2926.248369   84.917398
# median    3.000000     81000.000000       41667.000000  700.000000
# std       0.000000       150.000000           0.000000    9.000000
# 25%       0.000000      2877.500000           0.000000  100.000000
# 50%       0.000000      3812.500000        1188.500000  128.000000
# 75%       2.000000      5795.000000        2297.250000  166.750000
#
#         Loan_Amount_Term  Credit_History
# count         614.000000       614.00000
# max           342.410423         0.84202
# min           360.000000         1.00000
# mean           64.428629         0.36502
# median        480.000000         1.00000
# std            12.000000         0.00000
# ...

# %% [markdown]
# ### $Outlier$ $Analysis$

# %% [markdown]
# **Steps in Outlier analysis
#
#    - Step 1:Find the Q1,Q2,Q3
#
#         - np.percentaile(column data,q)
#
#    - Step 2: Calculate the IQR
#
#         - IQR = Q3-Q1
#
#    - Step 3: Calculate lower boundary and upper boundary
#
#         - lb: Q1-1.5IQR
#         - Ub: Q3+1.5IQR
#
#    - Step 4: Find the Outliers df
#
#         - c1: column data<lb
#         - c2: column data>ub
#         - c: appy the main condition
#         - main data[c]

# %%
###########--------Step-1------#########
Q1 = np.percentile(loan_df['LoanAmount'],25)
Q2 = np.percentile(loan_df['LoanAmount'],50)
Q3 = np.percentile(loan_df['LoanAmount'],75)

##########-------Step-2-------#########
IQR = Q3-Q1

##########-------Step-3-------#########
lb = Q1 - 1.5 * IQR
ub = Q3 + 1.5 * IQR

##########------Step-4--------#########
c1 = loan_df['LoanAmount'] < lb
c2 = loan_df['LoanAmount'] > ub
con = c1|c2

Loan_outliers_df = loan_df[con]
Loan_outliers_df

##########------Step-5------#######

c1 = loan_df['LoanAmount'] > lb
c2 = loan_df['LoanAmount'] < ub
con = c1&c2

Loan_non_outliers_df = loan_df[con]
Loan_non_outliers_df
# Out:
#       Loan_ID  Gender Married  Dependents     Education Self_Employed  \
# 0    LP001002    Male      No           0      Graduate            No
# 1    LP001003    Male     Yes           1      Graduate            No
# 2    LP001005    Male     Yes           0      Graduate           Yes
# 3    LP001006    Male     Yes           0  Not Graduate            No
# 4    LP001008    Male      No           0      Graduate            No
# ..        ...     ...     ...         ...           ...           ...
# 609  LP002978  Female      No           0      Graduate            No
# 610  LP002979    Male     Yes           3      Graduate            No
# 611  LP002983    Male     Yes           1      Graduate            No
# 612  LP002984    Male     Yes           2      Graduate            No
# 613  LP002990  Female      No           0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
len(Loan_outliers_df)
# Out:
# 41

# %% [markdown]
# **Compare original data with non outliers data**
#
# will plot histogram and box plot of the both

# %%
plt.hist(loan_df['LoanAmount'])
plt.hist(Loan_non_outliers_df['LoanAmount'])
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1).hist(loan_df['LoanAmount'])
plt.title('Loan_df')
plt.subplot(2,2,2).boxplot(loan_df['LoanAmount'])
plt.title('Loan_df')
plt.subplot(2,2,3).hist(Loan_non_outliers_df['LoanAmount'])
plt.title('Non_outlier_df')
plt.subplot(2,2,4).boxplot(Loan_non_outliers_df['LoanAmount'])
plt.title('Non_outlier_df')
plt.show()

# %% [markdown]
# ## How to deal outliers
#
# **Drop the outliers**
#
#    - we can drop the outliers if outlier percentage < 2%
#
#    - But this is not recommended , we lost other columns data also
#
#
# **Impute with Median values**
#
#    - As we know that Median does not affect by outliers
#
#    - So it is good prcatice we can impute outliers with Median value
#
# **Cap with Q3 or Q1 value**
#
#    - If outliers are presnt less than lower bound then fill with Q1
#
#    - If outliers are more than upper bound then fill with Q3

# %%
# Read the each observation from prevailing wage
# if that observation <lb or >ub : fill with median value
# else: keep as it is

# %%
# Import the packages
# Read the data

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

path=r'C:\Users\kanch\OneDrive\Naresh IT\Data science\data files\Loan Prediction\train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
###############--------step-1-------###############
Q1 = np.percentile(loan_df['LoanAmount'],25)
Q2 = np.percentile(loan_df['LoanAmount'],50)
Q3 = np.percentile(loan_df['LoanAmount'],75)

##########-------Step-2-------#########
IQR = Q3-Q1

##########-------Step-3-------#########
lb = Q1 - 1.5 * IQR
ub = Q3 + 1.5 * IQR


median = loan_df['LoanAmount'].median()

list1 = []

for i in loan_df['LoanAmount']:
    if i < lb or i > ub:
        list1.append(median)
        
    else:
        list1.append(i)
loan_df['NewLoanAmount']= list1

# %%
loan_df.fillna(method='bfill')
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
plt.boxplot(loan_df['NewLoanAmount'])
plt.show()

# %%
###############--------step-1-------###############
Q1 = np.percentile(loan_df['LoanAmount'],25)
Q2 = np.percentile(loan_df['LoanAmount'],50)
Q3 = np.percentile(loan_df['LoanAmount'],75)

##########-------Step-2-------#########
IQR = Q3-Q1

##########-------Step-3-------#########
lb = Q1 - 1.5 * IQR
ub = Q3 + 1.5 * IQR


median = loan_df['LoanAmount'].median()

c1 = loan_df['LoanAmount'] <lb
c2 = loan_df['LoanAmount'] >ub
con = c1|c2

t = median
f = loan_df['LoanAmount']

loan_df['new_LoanAmount'] = np.where(con,t,f)
plt.boxplot(loan_df['new_LoanAmount'])
plt.show()

# %% [markdown]
# ## Bi variate analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

path=r'C:\Users\kanch\OneDrive\Naresh IT\Data science\data files\Loan Prediction\train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %% [markdown]
# $Categorical$ vs $ Categorical

# %%
c1 = loan_df['Property_Area'] == 'Urban'
c2 = loan_df['Loan_Status'] == 'Y'
c3 = loan_df['Loan_Status'] == 'N'
approved_con    = c1 &c2
Notapproved_con = c1&c3

approved_count = len(loan_df[approved_con])
Notapproved_count = len(loan_df[Notapproved_con])

print(f'there are {approved_count} are approved for loan from urban')
print(f'there are {Notapproved_count} are not approved for loan from urban')
# Out:
# there are 133 are approved for loan from urban
# there are 69 are not approved for loan from urban

# %%
c1 = loan_df['Property_Area'] == 'Rural'
c2 = loan_df['Loan_Status'] == 'Y'
c3 = loan_df['Loan_Status'] == 'N'
approved_con    = c1 &c2
Notapproved_con = c1&c3

approved_count = len(loan_df[approved_con])
Notapproved_count = len(loan_df[Notapproved_con])

print(f'there are {approved_count} are approved for loan from Rural')
print(f'there are {Notapproved_count} are not approved for loan from Rural')
# Out:
# there are 110 are approved for loan from Rural
# there are 69 are not approved for loan from Rural

# %%
c1 = loan_df['Property_Area'] == 'Semiurban'
c2 = loan_df['Loan_Status'] == 'Y'
c3 = loan_df['Loan_Status'] == 'N'
approved_con    = c1 &c2
Notapproved_con = c1&c3

approved_count = len(loan_df[approved_con])
Notapproved_count = len(loan_df[Notapproved_con])

print(f'there are {approved_count} are approved for loan from Semiurban')
print(f'there are {Notapproved_count} are not approved for loan Semiurban')
# Out:
# there are 179 are approved for loan from Semiurban
# there are 54 are not approved for loan Semiurban

# %%
# Step -1: make the unique lables
labels = loan_df['Property_Area']. unique()
# step-2: create empty two lists
apporved_count=[]
denied_count = []

#step-3: Iterate through loop
for i in labels:
    c1 = loan_df['Property_Area']== i
    c2 = loan_df['Loan_Status']== 'Y'
    c3 = loan_df['Loan_Status']== 'N'
    approved_con = c1 &c2
    den_con = c1&c3
    apporved_count.append(len(loan_df[approved_con]))
    denied_count.append(len(loan_df[den_con]))
    
cols = ['Property_area','Apporved', 'Denied']
Approved_status_df = pd.DataFrame(zip(labels,apporved_count,denied_count),
                                 columns=cols)
Approved_status_df
# Out:
#   Property_area  Apporved  Denied
# 0         Urban       133      69
# 1         Rural       110      69
# 2     Semiurban       179      54

# %% [markdown]
# **pd,crosstab**
#
#    - will take two arguments
#    - index
#    - column

# %%
col1=[loan_df['Property_Area']]
col2=loan_df['Loan_Status']
result1=pd.crosstab(col1,col2)
result1
# Out:
# Loan_Status     N    Y
# Property_Area
# Rural          69  110
# Semiurban      54  179
# Urban          69  133

# %%
col1=[loan_df['Property_Area'],loan_df['Education']]
col2=loan_df['Loan_Status']
result2=pd.crosstab(col1,col2)
result2
# Out:
# Loan_Status                  N    Y
# Property_Area Education
# Rural         Graduate      47   84
#               Not Graduate  22   26
# Semiurban     Graduate      43  144
#               Not Graduate  11   35
# Urban         Graduate      50  112
#               Not Graduate  19   21

# %%
result1.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Property_Area'>

# %%
col1 = [loan_df['Property_Area'],loan_df['Education']]
col2 = loan_df['Loan_Status']
result2 = pd.crosstab(col2,col1)
result2.plot(kind='bar')
# Out:
# <Axes: xlabel='Loan_Status'>

# %%
loan = loan_df.corr(numeric_only=True)
plt.figure(figsize=(10,8))
sns.heatmap(loan,annot = True)
# Out:
# <Axes: >

# %% [markdown]
# **Convert categorical to numerical**

# %%
path=r'C:\Users\kanch\OneDrive\Naresh IT\Data science\data files\Loan Prediction\train_ctrUa4K.csv'
loan_df=pd.read_csv(path)
loan_df.head(10)
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
# 5  LP001011   Male     Yes          2      Graduate           Yes
# 6  LP001013   Male     Yes          0  Not Graduate            No
# 7  LP001014   Male     Yes         3+      Graduate            No
# 8  LP001018   Male     Yes          2      Graduate            No
# 9  LP001020   Male     Yes          1      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# ...

# %% [markdown]
# $Map$

# %%
loan_df['Loan_Status'].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
ld = {'Y': 0,'N':1}
loan_df['Loan_Status']=loan_df['Loan_Status'].map(ld)

# %%
loan_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...
