# %% [markdown]
# **importing necessary libreryis**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = r'C:\Users\kanch\OneDrive\Naresh IT\Data science\data files\Visadataset.csv'
visa_df = pd.read_csv(path)
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail(20)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25460  EZYV25461         Europe              Master's                  Y
# 25461  EZYV25462           Asia              Master's                  Y
# 25462  EZYV25463         Europe            Bachelor's                  N
# 25463  EZYV25464           Asia           High School                  N
# 25464  EZYV25465           Asia              Master's                  N
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25467  EZYV25468  North America              Master's                  N
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# ...

# %%
visa_df['education_of_employee']  # series
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
con = visa_df['education_of_employee']=='High School'
visa_df[con]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 0         EZYV01           Asia           High School                  N
# 11        EZYV12           Asia           High School                  Y
# 15        EZYV16           Asia           High School                  Y
# 23        EZYV24  North America           High School                  N
# 27        EZYV28           Asia           High School                  Y
# ...          ...            ...                   ...                ...
# 25463  EZYV25464           Asia           High School                  N
# 25465  EZYV25466  North America           High School                  N
# 25471  EZYV25472           Asia           High School                  N
# 25472  EZYV25473           Asia           High School                  N
# 25476  EZYV25477           Asia           High School                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
con = visa_df['education_of_employee']=='High School'
len(visa_df[con])
# Out:
# 3420

# %%
con = visa_df['education_of_employee']=="Master's"
len(visa_df[con])
# Out:
# 9634

# %%
con = visa_df['education_of_employee']=="Bachelor's"
len(visa_df[con])
# Out:
# 10234

# %%
con = visa_df['education_of_employee']=="Doctorate"
len(visa_df[con])
# Out:
# 2192

# %%
unique_labels = visa_df['education_of_employee'].unique()
for i in unique_labels:
    con = visa_df['education_of_employee'] == i
    print(i,':',len(visa_df[con]))
# Out:
# High School : 3420
# Master's : 9634
# Bachelor's : 10234
# Doctorate : 2192

# %%
unique_labels = visa_df['education_of_employee'].unique()
count = []
for i in unique_labels:
    con = visa_df['education_of_employee'] == i
    count.append(len(visa_df[con]))
    
############################################################
education_df = pd.DataFrame(zip(unique_labels,count),columns=['education_of_employee','count'])
education_df.to_csv('education_df.csv',index = False)

# %%
visa_df  # total data frame
visa_df['education_of_employee'] # specific clumn
visa_df['education_of_employee']=='High School' # specific lable
###############################################################
unique_labels = visa_df['education_of_employee'].unique()
count = []
for i in unique_labels:
    con = visa_df['education_of_employee'] == i
    count.append(len(visa_df[con]))
    
############################################################
education_df = pd.DataFrame(zip(unique_labels,count),columns=['education_of_employee','count'])
education_df.to_csv('education_df.csv',index = False)

# %%
education_df
# Out:
#   education_of_employee  count
# 0           High School   3420
# 1              Master's   9634
# 2            Bachelor's  10234
# 3             Doctorate   2192

# %% [markdown]
# $value$-$counts$

# %%
education_vc = visa_df['education_of_employee'].value_counts() # series
education_vc
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
visa_df
visa_df['education_of_employee']
visa_df['education_of_employee'].unique()
visa_df['education_of_employee'].nunique()
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df['education_of_employee']
# Out:
# 0        High School
# 1           Master's
# 2         Bachelor's
# 3         Bachelor's
# 4           Master's
#             ...
# 25475     Bachelor's
# 25476    High School
# 25477       Master's
# 25478       Master's
# 25479     Bachelor's
# Name: education_of_employee, Length: 25480, dtype: object

# %%
visa_df['education_of_employee'].unique()
# Out:
# array(['High School', "Master's", "Bachelor's", 'Doctorate'], dtype=object)

# %%
list(set(visa_df['education_of_employee'].unique()))
# Out:
# ['Doctorate', "Bachelor's", "Master's", 'High School']

# %%
visa_df['education_of_employee'].nunique()
# Out:
# 4

# %%
visa_df['education_of_employee'].value_counts()
# Out:
# education_of_employee
# Bachelor's     10234
# Master's        9634
# High School     3420
# Doctorate       2192
# Name: count, dtype: int64

# %%
- con = visa_df[<(column1_condition)> & <(column2_condition)>]
# Out:
#   Cell In[23], line 1
#     - con = visa_df[<(column1_condition)> & <(column2_condition)>]
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
con = visa_df[(visa_df['education_of_employee']=="Master's")&(visa_df['continent']== 'Asia')]
con
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 1         EZYV02      Asia              Master's                  Y
# 5         EZYV06      Asia              Master's                  Y
# 10        EZYV11      Asia              Master's                  N
# 14        EZYV15      Asia              Master's                  Y
# 17        EZYV18      Asia              Master's                  Y
# ...          ...       ...                   ...                ...
# 25458  EZYV25459      Asia              Master's                  Y
# 25461  EZYV25462      Asia              Master's                  Y
# 25464  EZYV25465      Asia              Master's                  N
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 1                         N             2412         2002
# ...

# %%
con = visa_df[(visa_df['education_of_employee']=="Master's")&(visa_df['continent']== 'Asia')&(visa_df['has_job_experience']=='N')&(visa_df['requires_job_training']=='Y')]
con
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 60        EZYV61      Asia              Master's                  N
# 142      EZYV143      Asia              Master's                  N
# 261      EZYV262      Asia              Master's                  N
# 289      EZYV290      Asia              Master's                  N
# 348      EZYV349      Asia              Master's                  N
# ...          ...       ...                   ...                ...
# 24933  EZYV24934      Asia              Master's                  N
# 25001  EZYV25002      Asia              Master's                  N
# 25043  EZYV25044      Asia              Master's                  N
# 25055  EZYV25056      Asia              Master's                  N
# 25067  EZYV25068      Asia              Master's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 60                        Y             5340         2010
# ...

# %%
education_vc = visa_df['education_of_employee'].value_counts()
l1=education_vc.keys()
l2=education_vc.values
education_vc_df=pd.DataFrame(zip(l1,l2),columns=['education_of_employee','count'])
education_vc_df
# Out:
#   education_of_employee  count
# 0            Bachelor's  10234
# 1              Master's   9634
# 2           High School   3420
# 3             Doctorate   2192

# %% [markdown]
# **Bar chart**

# %%
plt.figure(figsize=(10,6))
plt.bar('education_of_employee','count',data =  education_vc_df)
plt.xlabel('education_of_employee')

plt.ylabel('count')
plt.title('bar plot')

plt.show()

# %% [markdown]
# $count$ - $plot$

# %%
plt.figure(figsize=(10,6))
l = visa_df['education_of_employee'].value_counts().keys()
sns.countplot(data=visa_df, x='education_of_employee',order=l)
plt.title('Count Plot')
plt.show()

# %%
con = visa_df[(visa_df['education_of_employee']=="Master's")&(visa_df['continent']== 'Asia')&(visa_df['has_job_experience']=='N')&(visa_df['requires_job_training']=='Y')]
con
